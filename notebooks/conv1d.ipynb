# %%
# %matplotlib inline 

import pandas

# %%
data1 = pandas.read_csv('../losses/_timbral_classifier_/losses.csv')
d = data1['D_A'] + data1['D_B']
d[::].plot()
print(data1[d.index == 3200])
# Out:
# Empty DataFrame
# Columns: [epoch, iter, D_A, D_B]
# Index: []
