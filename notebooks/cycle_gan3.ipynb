# %%
# %matplotlib inline
import pandas

data = pandas.read_csv('../losses/p2g_conv2d_resnet2d_timbral_wgangp/losses.csv')

(data['D_A'] + data['D_B']).plot(ylim=(0,4))
(data['G_A'] + data['G_B']).plot()
(data['cycle_A'] + data['cycle_B']).plot()
(data['idt_A'] + data['idt_B']).plot()
