# %%
# %matplotlib inline 

import pandas

# %%
data1 = pandas.read_csv('../losses/p2g_conv2d_resnet2d_timbral_cqt/losses.csv')
d = data1['D_A'] + data1['D_B']
g = data1['G_A'] + data1['G_B']
c = data1['cycle_A'] + data1['cycle_B']
d[::].plot(ylim=(0,20))
g[::].plot()
c[::].plot()
